# %%
import pandas as pd
import numpy as ns
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data = pd.read_csv("IPL_Ball_by_Ball_2022.csv")

# %%
df=pd.DataFrame(data)

# %%
data.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
data.tail()
# Out:
#             ID  innings  overs  ballnumber      batter    bowler non-striker  \
# 17907  1304047        2     17           5     SS Iyer  DJ Bravo  SP Jackson
# 17908  1304047        2     17           6  SP Jackson  DJ Bravo     SS Iyer
# 17909  1304047        2     18           1  SP Jackson  AF Milne     SS Iyer
# 17910  1304047        2     18           2     SS Iyer  AF Milne  SP Jackson
# 17911  1304047        2     18           3     SS Iyer  AF Milne  SP Jackson
#
#       extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17907        NaN            1           0          1             0
# 17908        NaN            1           0          1             0
# 17909        NaN            1           0          1             0
# 17910        NaN            2           0          2             0
# 17911        NaN            4           0          4             0
#
#        isWicketDelivery player_out kind fielders_involved  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17912 entries, 0 to 17911
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 17912 non-null  int64
#  1   innings            17912 non-null  int64
#  2   overs              17912 non-null  int64
#  3   ballnumber         17912 non-null  int64
#  4   batter             17912 non-null  object
#  5   bowler             17912 non-null  object
#  6   non-striker        17912 non-null  object
#  7   extra_type         1050 non-null   object
#  8   batsman_run        17912 non-null  int64
#  9   extras_run         17912 non-null  int64
#  10  total_run          17912 non-null  int64
#  11  non_boundary       17912 non-null  int64
#  12  isWicketDelivery   17912 non-null  int64
#  13  player_out         912 non-null    object
#  14  kind               912 non-null    object
#  15  fielders_involved  704 non-null    object
# ...

# %%
data.shape
# Out:
# (17912, 17)

# %%
data.describe()
# Out:
#                  ID       innings         overs    ballnumber   batsman_run  \
# count  1.791200e+04  17912.000000  17912.000000  17912.000000  17912.000000
# mean   1.304524e+06      1.485317      9.290085      3.652077      1.286958
# std    1.843446e+03      0.499798      5.690914      1.837818      1.701842
# min    1.304047e+06      1.000000      0.000000      1.000000      0.000000
# 25%    1.304065e+06      1.000000      4.000000      2.000000      0.000000
# 50%    1.304084e+06      1.000000      9.000000      4.000000      1.000000
# 75%    1.304102e+06      2.000000     14.000000      5.000000      1.000000
# max    1.312200e+06      2.000000     19.000000     10.000000      6.000000
#
#          extras_run     total_run  non_boundary  isWicketDelivery
# count  17912.000000  17912.000000  17912.000000      17912.000000
# mean       0.074978      1.361936      0.000167          0.050916
# std        0.372878      1.688991      0.012941          0.219831
# ...

# %%
data.isnull()
# Out:
#           ID  innings  overs  ballnumber  batter  bowler  non-striker  \
# 0      False    False  False       False   False   False        False
# 1      False    False  False       False   False   False        False
# 2      False    False  False       False   False   False        False
# 3      False    False  False       False   False   False        False
# 4      False    False  False       False   False   False        False
# ...      ...      ...    ...         ...     ...     ...          ...
# 17907  False    False  False       False   False   False        False
# 17908  False    False  False       False   False   False        False
# 17909  False    False  False       False   False   False        False
# 17910  False    False  False       False   False   False        False
# 17911  False    False  False       False   False   False        False
#
#        extra_type  batsman_run  extras_run  total_run  non_boundary  \
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17907    False
# 17908    False
# 17909    False
# 17910    False
# 17911    False
# Length: 17912, dtype: bool

# %%
data.value_counts()
# Out:
# ID       innings  overs  ballnumber  batter       bowler             non-striker  extra_type  batsman_run  extras_run  total_run  non_boundary  isWicketDelivery  player_out   kind     fielders_involved  BattingTeam
# 1304047  1        7      6           RV Uthappa   CV Varun           AT Rayudu    wides       0            1           1          0             1                 RV Uthappa   stumped  SP Jackson         Chennai Super Kings    1
# 1304055  2        18     9           KA Pollard   M Prasidh Krishna  M Ashwin     noballs     0            1           1          0             1                 M Ashwin     run out  SV Samson          Mumbai Indians         1
# 1304097  1        18     3           Tilak Varma  LH Ferguson        TH David     noballs     0            1           1          0             1                 Tilak Varma  run out  HH Pandya          Mumbai Indians         1
# ...

# %%
data.dtypes
# Out:
# ID                    int64
# innings               int64
# overs                 int64
# ballnumber            int64
# batter               object
# bowler               object
# non-striker          object
# extra_type           object
# batsman_run           int64
# extras_run            int64
# total_run             int64
# non_boundary          int64
# isWicketDelivery      int64
# player_out           object
# kind                 object
# fielders_involved    object
# BattingTeam          object
# dtype: object

# %%
sns.boxplot(data["innings"])
# Out:
# <Axes: >

# %%
sns.boxplot(data["overs"])
# Out:
# <Axes: >

# %%
sns.boxplot(data["ballnumber"])
# Out:
# <Axes: >

# %%
sns.boxplot(data["batsman_run"])
# Out:
# <Axes: >

# %%
data.plot(kind='line')
# Out:
# <Axes: >

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'innings'}>,
#         <Axes: title={'center': 'overs'}>],
#        [<Axes: title={'center': 'ballnumber'}>,
#         <Axes: title={'center': 'batsman_run'}>,
#         <Axes: title={'center': 'extras_run'}>],
#        [<Axes: title={'center': 'total_run'}>,
#         <Axes: title={'center': 'non_boundary'}>,
#         <Axes: title={'center': 'isWicketDelivery'}>]], dtype=object)

# %%
data.plot()
# Out:
# <Axes: >

# %%
df[["ID","innings"]]
# Out:
#             ID  innings
# 0      1312200        1
# 1      1312200        1
# 2      1312200        1
# 3      1312200        1
# 4      1312200        1
# ...        ...      ...
# 17907  1304047        2
# 17908  1304047        2
# 17909  1304047        2
# 17910  1304047        2
# 17911  1304047        2
#
# [17912 rows x 2 columns]

# %%
df[df.total_run > 10]
# Out:
# Empty DataFrame
# Columns: [ID, innings, overs, ballnumber, batter, bowler, non-striker, extra_type, batsman_run, extras_run, total_run, non_boundary, isWicketDelivery, player_out, kind, fielders_involved, BattingTeam]
# Index: []

# %%
df.sort_values("total_run")
# Out:
#             ID  innings  overs  ballnumber           batter          bowler  \
# 0      1312200        1      0           1      YBK Jaiswal  Mohammed Shami
# 5728   1304097        2     15           1  B Sai Sudharsan      KA Pollard
# 13043  1304067        2     15           6    KS Williamson     LH Ferguson
# 5724   1304097        2     14           3  B Sai Sudharsan     K Kartikeya
# 13045  1304067        2     16           1    KS Williamson       HH Pandya
# ...        ...      ...    ...         ...              ...             ...
# 8153   1304087        2      7           4      Lalit Yadav    Harshit Rana
# 17793  1304047        1     18           7         MS Dhoni     Shivam Mavi
# 14483  1304061        2     13           1        Q de Kock        A Nortje
# 2108   1304112        2      9           3      SW Billings      Avesh Khan
# 8083   1304087        1     16           3           N Rana     Lalit Yadav
#
# ...

# %%
data = data.pivot("innings", "Id", "overs")
ax = sns.heatmap(data)
plt.show()
# Out:
# C:\Users\Acs\AppData\Local\Temp\ipykernel_592\3696551014.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   data = data.pivot("innings", "Id", "overs")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
